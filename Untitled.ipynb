# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('Iris.csv',index_col=False)

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.stripplot(x='Species',y='SepalLengthCm',data=data,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')

# %%
from sklearn.model_selection import train_test_split
X = data.iloc[:,1:5]
y = data['Species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=50, shuffle=True)
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 15             5.7           4.4            1.5           0.4
# 143            6.8           3.2            5.9           2.3
# 26             5.0           3.4            1.6           0.4
# 48             5.3           3.7            1.5           0.2
# 50             7.0           3.2            4.7           1.4
# 49             5.0           3.3            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 87             6.3           2.3            4.4           1.3
# 81             5.5           2.4            3.7           1.0
# 100            6.3           3.3            6.0           2.5
# 124            6.7           3.3            5.7           2.1
# 33             5.5           4.2            1.4           0.2
# 16             5.4           3.9            1.3           0.4
# 58             6.6           2.9            4.6           1.3
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
knn.score(X_test, y_test)
# Out:
# 0.98

# %%
print(X_test.head(2))
print(y_test.head(2))
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 71            6.1           2.8            4.0           1.3
# 23            5.1           3.3            1.7           0.5
# 71    Iris-versicolor
# 23        Iris-setosa
# Name: Species, dtype: object

# %%
knn.predict([[6.1,2.8,4.0,1.3]])
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
y_test.iloc[0]
# Out:
# 'Iris-versicolor'

# %%
knn.predict([[5.1,3.3,1.7,0.5]])
# Out:
# array(['Iris-setosa'], dtype=object)
